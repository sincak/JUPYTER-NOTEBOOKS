# %% [markdown]
# # Exploring Beat Frequencies using the `Audio` Object

# %% [markdown]
# This example uses the `Audio` object and Matplotlib to explore the phenomenon of beat frequencies.

# %%
# Imports for JupyterLite
# %pip install -q ipywidgets matplotlib numpy
# Out:
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/sympy-1.14.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/nvidia_cuda_runtime_cu12-12.8.90-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/nvidia_cusolver_cu12-11.7.3.90-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/nvidia_nvjitlink_cu12-12.8.93-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/nvidia_cuda_nvrtc_cu12-12.8.93-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/torchinfo-1.8.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/nvidia_nccl_cu12-2.27.3-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/triton-3.4.0-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/nvidia_cusparse_cu12-12.5.8.93-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/nvidia_nvtx_cu12-12.8.90-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/nvidia_curand_cu12-10.3.9.90-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/nvidia_cudnn_cu12-9.10.2.21-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/nvidia_cuda_cupti_cu12-12.8.90-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/nvidia_cublas_cu12-12.8.4.1-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/torch-2.8.0-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/nvidia_cusparselt_cu12-0.7.1-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/nvidia_cufft_cu12-11.3.3.83-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/nvidia_cufile_cu12-1.13.1.3-py3.12-linux-x86_64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /home/nitoy/.local/bin/anaconda/lib/python3.12/site-packages/galerkin_transformer-0.2.1-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
from ipywidgets import interactive
from IPython.display import Audio, display
import numpy as np

# %%
def beat_freq(f1=220.0, f2=224.0):
    max_time = 3
    rate = 8000
    times = np.linspace(0,max_time,rate*max_time)
    signal = np.sin(2*np.pi*f1*times) + np.sin(2*np.pi*f2*times)
    display(Audio(data=signal, rate=rate))
    return signal

# %%
v = interactive(beat_freq, f1=(200.0,800.0), f2=(200.0,800.0), f3=(200.0,800.0), f4=(200.0,800.0), f5=(200.0,800.0), f6=(200.0,800.0))
display(v)
# Out:
# interactive(children=(FloatSlider(value=220.0, description='f1', max=300.0, min=200.0), FloatSlider(value=224.…

# %%
v.kwargs
# Out:
# {'f1': 220.0, 'f2': 224.0}

# %%
f1, f2 = v.children[:2]
f1.value = 255
f2.value = 260
plt.plot(v.result[0:6000]);
