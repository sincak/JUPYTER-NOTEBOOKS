# %% [markdown]
# <a href="https://colab.research.google.com/github/sincak/JUPYTER-NOTEBOOKS/blob/main/Boxes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# `HBox` and `VBox` are simple layout classes provide by `ipywidgets` framework. To read more on layouts, refer to [this](https://ipywidgets.readthedocs.io/en/latest/examples/Widget%20Styling.html#Natural-sizes,-and-arrangements-using-HBox-and-VBox).

# %%
import ipywidgets as widgets
from google.colab import output
output.enable_custom_widget_manager()

# %%
title_widget = widgets.HTML('<em>Vertical Box Example</em>')
slider = widgets.IntSlider()
widgets.VBox([title_widget, slider])

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %% [markdown]
# from google.colab import output<p/>
# output.disable_custom_widget_manager()

# %%
from ipywidgets.embed import embed_minimal_html
# writes all data needed so the exported HTML shows the widget with the same state
embed_minimal_html('widgets.html', views=[title_widget], title='My widgets')
